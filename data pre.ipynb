# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
Raw_DIR= r'C:\Users\DELL\Downloads\Driver-Drowsiness-Detection-using-Deep-Learning-main\mrlEyes_2018_01'
for dirpath, dirname, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i, dst=r'C:\Users\DELL\Downloads\Driver-Drowsiness-Detection-using-Deep-Learning-main\mrlEyes_2018_01\Prepared_Data\Close Eyes')
        
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i, dst=r'C:\Users\DELL\Downloads\Driver-Drowsiness-Detection-using-Deep-Learning-main\mrlEyes_2018_01\Prepared_Data\Open Eyes')
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [04:46<00:00, 35.76it/s]
# 0it [00:00, ?it/s]
#   0%|                                                                                        | 0/41946 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# SameFileError                             Traceback (most recent call last)
# Cell In[2], line 5
#       3 for i in tqdm([f for f in filenames if f.endswith('.png')]):
#       4     if i.split('_')[4]=='0':
# ----> 5         shutil.copy(src=dirpath+'/'+i, dst=r'C:\Users\DELL\Downloads\Driver-Drowsiness-Detection-using-Deep-Learning-main\mrlEyes_2018_01\Prepared_Data\Close Eyes')
#       7     elif i.split('_')[4]=='1':
# ...
